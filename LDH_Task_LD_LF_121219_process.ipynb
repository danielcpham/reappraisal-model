# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os
import sys

# %%
path = Path(os.getcwd()) / 'output' / 'results_LDH.xlsx'

# %%
path2 = Path(os.getcwd(), 'LDH_Task_LD_LF_121219.xlsx')
path2

df_orig = pd.read_excel(path2)
df_orig.head(10)
# Out:
#    addcode Group Bin  Subj_ID  daycode    Cue1    Cue2 Group_ID  ReappSuccess  \
# 0  XAQ1001     X  AQ     1001        1    LOOK  CHANGE      OBJ      1.200000
# 1  XAQ1001     X  AQ     1001        2    LOOK  CHANGE      OBJ      0.677778
# 2  XAQ1001     X  AQ     1001        3    LOOK  CHANGE      OBJ           NaN
# 3  YAQ2001     Y  AQ     2001        1    LOOK  CHANGE      FAR      1.000000
# 4  XAQ1001     X  AQ     1001        4    LOOK  CHANGE      OBJ     -0.088889
# 5  XAQ1001     X  AQ     1001        5    LOOK  CHANGE      OBJ     -0.100000
# 6  YAQ2001     Y  AQ     2001        2    LOOK  CHANGE      FAR      2.100000
# 7  YBR2002     Y  BR     2002        1  CHANGE    LOOK      FAR           NaN
# 8  YAQ2001     Y  AQ     2001        3    LOOK  CHANGE      FAR      3.033333
# 9  YAQ2001     Y  AQ     2001        4    LOOK  CHANGE      FAR      0.900000
#
#   Condition    Rating                                       TextResponse
# 0    RegNeg  2.100000  this is a photo of a man and woman who look li...
# 1    RegNeg  2.222222  this is a cut off hand. it looks really bloody...
# 2    RegNeg       NaN  this is a baby in some hospital. the baby look...
# 3    RegNeg  1.800000  There was a couple arguing, with what looks li...
# 4    RegNeg  2.200000  this looks like a police officer pushing down ...
# 5    RegNeg  1.800000  there is a woman looking down and to the side ...
# 6    RegNeg  2.300000  This is a picture of a hand that has been cut ...
# 7    RegNeg       NaN  Someone's insides are cut open some time in th...
# 8    RegNeg  1.666667  The baby was in the hospital. The baby seemed ...
# 9    RegNeg  2.400000  There was a situation that involved police and...

# %%
df = pd.read_excel(path, sheet_name='farAway', index_col='serial')

# %%
df_combine = pd.merge(left=df_orig, right=df, left_on='TextResponse', right_on='response', how='left')
df_combine.to_csv("output/results_LDH_farAway_4.csv")

# %%
df_processed_obj = pd.read_excel(Path(os.getcwd()) / 'output' / "results_LDH.xlsx", sheet_name='farAway', index_col='serial')
df_new = pd.merge(left=df, right=df_processed_obj, left_on='TextResponse', right_on='response', how='left')
df_new.to_csv('output/results_LDH_farAway_3.csv')

# %%
df_new.head(10)
# Out:
#    addcode Group Bin  Subj_ID  daycode    Cue1    Cue2 Group_ID  ReappSuccess  \
# 0  XAQ1001     X  AQ     1001        1    LOOK  CHANGE      OBJ      1.200000
# 1  XAQ1001     X  AQ     1001        2    LOOK  CHANGE      OBJ      0.677778
# 2  XAQ1001     X  AQ     1001        3    LOOK  CHANGE      OBJ           NaN
# 3  YAQ2001     Y  AQ     2001        1    LOOK  CHANGE      FAR      1.000000
# 4  XAQ1001     X  AQ     1001        4    LOOK  CHANGE      OBJ     -0.088889
# 5  XAQ1001     X  AQ     1001        5    LOOK  CHANGE      OBJ     -0.100000
# 6  YAQ2001     Y  AQ     2001        2    LOOK  CHANGE      FAR      2.100000
# 7  YBR2002     Y  BR     2002        1  CHANGE    LOOK      FAR           NaN
# 8  YAQ2001     Y  AQ     2001        3    LOOK  CHANGE      FAR      3.033333
# 9  YAQ2001     Y  AQ     2001        4    LOOK  CHANGE      FAR      0.900000
#
#   Condition    Rating                                       TextResponse  \
# 0    RegNeg  2.100000  this is a photo of a man and woman who look li...
# 1    RegNeg  2.222222  this is a cut off hand. it looks really bloody...
# 2    RegNeg       NaN  this is a baby in some hospital. the baby look...
# 3    RegNeg  1.800000  There was a couple arguing, with what looks li...
# 4    RegNeg  2.200000  this looks like a police officer pushing down ...
# 5    RegNeg  1.800000  there is a woman looking down and to the side ...
# 6    RegNeg  2.300000  This is a picture of a hand that has been cut ...
# 7    RegNeg       NaN  Someone's insides are cut open some time in th...
# 8    RegNeg  1.666667  The baby was in the hospital. The baby seemed ...
# 9    RegNeg  2.400000  There was a situation that involved police and...
#
#                                             response     score    observed
# 0  this is a photo of a man and woman who look li...  2.100000   81.023633
# 1  this is a cut off hand. it looks really bloody...  2.222222   89.457537
# 2                                                NaN       NaN         NaN
# 3  There was a couple arguing, with what looks li...  1.800000   66.236203
# 4  this looks like a police officer pushing down ...  2.200000  100.636141
# 5  there is a woman looking down and to the side ...  1.800000   79.859059
# 6  This is a picture of a hand that has been cut ...  2.300000   79.549093
# 7                                                NaN       NaN         NaN
# 8  The baby was in the hospital. The baby seemed ...  1.666667   58.624194
# 9  There was a situation that involved police and...  2.400000   60.465709

# %%
pd.read_csv("output/results_LDH_farAway_3.csv")
# Out:
#       Unnamed: 0  addcode Group Bin  Subj_ID  daycode    Cue1    Cue2  \
# 0              0  XAQ1001     X  AQ     1001        1    LOOK  CHANGE
# 1              1  XAQ1001     X  AQ     1001        2    LOOK  CHANGE
# 2              2  XAQ1001     X  AQ     1001        3    LOOK  CHANGE
# 3              3  YAQ2001     Y  AQ     2001        1    LOOK  CHANGE
# 4              4  XAQ1001     X  AQ     1001        4    LOOK  CHANGE
# 5              5  XAQ1001     X  AQ     1001        5    LOOK  CHANGE
# 6              6  YAQ2001     Y  AQ     2001        2    LOOK  CHANGE
# 7              7  YBR2002     Y  BR     2002        1  CHANGE    LOOK
# 8              8  YAQ2001     Y  AQ     2001        3    LOOK  CHANGE
# 9              9  YAQ2001     Y  AQ     2001        4    LOOK  CHANGE
# 10            10  YBR2002     Y  BR     2002        2  CHANGE    LOOK
# 11            11  YBR2002     Y  BR     2002        3  CHANGE    LOOK
# 12            12  YAQ2001     Y  AQ     2001        5    LOOK  CHANGE
# 13            13  XAS1003     X  AS     1003        1    LOOK  CHANGE
# 14            14  YAS2003     Y  AS     2003        1    LOOK  CHANGE
# 15            15  YBR2002     Y  BR     2002        4  CHANGE    LOOK
# 16            16  YAS2003     Y  AS     2003        2    LOOK  CHANGE
# 17            17  XAS1003     X  AS     1003        2    LOOK  CHANGE
# 18            18  YAS2003     Y  AS     2003        3    LOOK  CHANGE
# 19            19  YBR2002     Y  BR     2002        5  CHANGE    LOOK
# 20            20  XAS1003     X  AS     1003        3    LOOK  CHANGE
# 21            21  ZCS3003     Z  CS     3003        1    LOOK    LOOK
# 22            22  XBT1004     X  BT     1004        1  CHANGE    LOOK
# 23            23  YAS2003     Y  AS     2003        4    LOOK  CHANGE
# 24            24  XAS1003     X  AS     1003        4    LOOK  CHANGE
# 25            25  YAS2003     Y  AS     2003        5    LOOK  CHANGE
# 26            26  ZCS3003     Z  CS     3003        2    LOOK    LOOK
# 27            27  XAS1003     X  AS     1003        5    LOOK  CHANGE
# 28            28  XBT1004     X  BT     1004        2  CHANGE    LOOK
# 29            29  ZCS3003     Z  CS     3003        3    LOOK    LOOK
# ...          ...      ...   ...  ..      ...      ...     ...     ...
# 1608        1608  XBR1042     X  BR     1042        1  CHANGE    LOOK
# 1609        1609  XAQ1041     X  AQ     1041        2    LOOK  CHANGE
# 1610        1610  YAQ2041     Y  AQ     2041        2    LOOK  CHANGE
# 1611        1611  ZCQ3041     Z  CQ     3041        2    LOOK    LOOK
# 1612        1612  XBR1042     X  BR     1042        2  CHANGE    LOOK
# 1613        1613  YBT2040     Y  BT     2040        2  CHANGE    LOOK
# 1614        1614  ZCT3040     Z  CT     3040        2    LOOK    LOOK
# 1615        1615  YAQ2041     Y  AQ     2041        3    LOOK  CHANGE
# 1616        1616  ZCT3040     Z  CT     3040        3    LOOK    LOOK
# 1617        1617  ZCQ3041     Z  CQ     3041        3    LOOK    LOOK
# 1618        1618  YBT2040     Y  BT     2040        3  CHANGE    LOOK
# 1619        1619  XAQ1041     X  AQ     1041        3    LOOK  CHANGE
# 1620        1620  XBR1042     X  BR     1042        3  CHANGE    LOOK
# 1621        1621  XAQ1041     X  AQ     1041        4    LOOK  CHANGE
# 1622        1622  XAS1043     X  AS     1043        1    LOOK  CHANGE
# 1623        1623  XBR1042     X  BR     1042        4  CHANGE    LOOK
# 1624        1624  ZCQ3041     Z  CQ     3041        4    LOOK    LOOK
# 1625        1625  YAQ2041     Y  AQ     2041        4    LOOK  CHANGE
# 1626        1626  YBT2040     Y  BT     2040        4  CHANGE    LOOK
# 1627        1627  ZCT3040     Z  CT     3040        4    LOOK    LOOK
# 1628        1628  XAS1043     X  AS     1043        2    LOOK  CHANGE
# 1629        1629  ZCT3040     Z  CT     3040        5    LOOK    LOOK
# 1630        1630  XAQ1041     X  AQ     1041        5    LOOK  CHANGE
# 1631        1631  YAQ2041     Y  AQ     2041        5    LOOK  CHANGE
# 1632        1632  YBT2040     Y  BT     2040        5  CHANGE    LOOK
# 1633        1633  XBR1042     X  BR     1042        5  CHANGE    LOOK
# 1634        1634  ZCQ3041     Z  CQ     3041        5    LOOK    LOOK
# 1635        1635  XAS1043     X  AS     1043        3    LOOK  CHANGE
# 1636        1636  XAS1043     X  AS     1043        4    LOOK  CHANGE
# 1637        1637  XAS1043     X  AS     1043        5    LOOK  CHANGE
#
#      Group_ID  ReappSuccess Condition    Rating  \
# 0         OBJ      1.200000    RegNeg  2.100000
# 1         OBJ      0.677778    RegNeg  2.222222
# 2         OBJ           NaN    RegNeg       NaN
# 3         FAR      1.000000    RegNeg  1.800000
# 4         OBJ     -0.088889    RegNeg  2.200000
# 5         OBJ     -0.100000    RegNeg  1.800000
# 6         FAR      2.100000    RegNeg  2.300000
# 7         FAR           NaN    RegNeg       NaN
# 8         FAR      3.033333    RegNeg  1.666667
# 9         FAR      0.900000    RegNeg  2.400000
# 10        FAR     -0.133333    RegNeg  4.333333
# 11        FAR      0.450000    RegNeg  4.750000
# 12        FAR      0.400000    RegNeg  1.400000
# 13        OBJ           NaN    RegNeg       NaN
# 14        FAR      1.777778    RegNeg  2.222222
# 15        FAR     -1.600000    RegNeg  5.400000
# 16        FAR      2.466667    RegNeg  3.333333
# 17        OBJ      3.100000    RegNeg  2.000000
# 18        FAR      1.000000    RegNeg  2.900000
# 19        FAR     -1.700000    RegNeg  4.400000
# 20        OBJ      2.700000    RegNeg  1.300000
# 21       LOOK           NaN    RegNeg       NaN
# 22        OBJ      0.111111    RegNeg  1.000000
# 23        FAR      0.100000    RegNeg  2.700000
# 24        OBJ      0.200000    RegNeg  1.800000
# 25        FAR      1.200000    RegNeg  3.300000
# 26       LOOK           NaN    RegNeg       NaN
# 27        OBJ      2.400000    RegNeg  1.900000
# 28        OBJ      0.000000    RegNeg  1.000000
# 29       LOOK           NaN    RegNeg       NaN
# ...       ...           ...       ...       ...
# 1608      OBJ           NaN  LookNeut  1.555556
# 1609      OBJ           NaN  LookNeut  1.000000
# 1610      FAR           NaN  LookNeut  1.875000
# 1611     LOOK           NaN  LookNeut  1.000000
# 1612      OBJ           NaN  LookNeut  1.000000
# 1613      FAR           NaN  LookNeut  1.000000
# 1614     LOOK           NaN  LookNeut  1.333333
# 1615      FAR           NaN  LookNeut  1.285714
# 1616     LOOK           NaN  LookNeut  1.333333
# 1617     LOOK           NaN  LookNeut  1.000000
# 1618      FAR           NaN  LookNeut  1.000000
# 1619      OBJ           NaN  LookNeut  1.000000
# 1620      OBJ           NaN  LookNeut  1.125000
# 1621      OBJ           NaN  LookNeut  1.000000
# 1622      OBJ           NaN  LookNeut  1.000000
# 1623      OBJ           NaN  LookNeut       NaN
# 1624     LOOK           NaN  LookNeut  1.000000
# 1625      FAR           NaN  LookNeut  1.333333
# 1626      FAR           NaN  LookNeut  1.000000
# 1627     LOOK           NaN  LookNeut  1.500000
# 1628      OBJ           NaN  LookNeut  1.000000
# 1629     LOOK           NaN  LookNeut  1.000000
# 1630      OBJ           NaN  LookNeut  1.000000
# 1631      FAR           NaN  LookNeut       NaN
# 1632      FAR           NaN  LookNeut  1.000000
# 1633      OBJ           NaN  LookNeut  1.100000
# 1634     LOOK           NaN  LookNeut  1.000000
# 1635      OBJ           NaN  LookNeut  1.000000
# 1636      OBJ           NaN  LookNeut  1.000000
# 1637      OBJ           NaN  LookNeut  1.000000
#
#                                            TextResponse  \
# 0     this is a photo of a man and woman who look li...
# 1     this is a cut off hand. it looks really bloody...
# 2     this is a baby in some hospital. the baby look...
# 3     There was a couple arguing, with what looks li...
# 4     this looks like a police officer pushing down ...
# 5     there is a woman looking down and to the side ...
# 6     This is a picture of a hand that has been cut ...
# 7     Someone's insides are cut open some time in th...
# 8     The baby was in the hospital. The baby seemed ...
# 9     There was a situation that involved police and...
# 10    In the past, a man holds a sobbing child. Why ...
# 11    Its the future, a newborn is in the NICU recei...
# 12    There was an argument where a guy was berating...
# 13    A man is being held down by a police officer, ...
# 14    A police officer is arresting someone in the p...
# 15    A woman was beaten badly and her face is blood...
# 16    A very sick child is hooked up to a lot of mac...
# 17    A baby is having a treatment in an emergency r...
# 18    Two people are in an argument while their soni...
# 19    In the past a boy has a gash in his face. It's...
# 20    Two adults are arguing at each other, and a bo...
# 21                                                  NaN
# 22    Bloody face, white individual. very white righ...
# 23    A couple is having an argument some time ago i...
# 24    A man is yelling at a woman and is pointing hi...
# 25    This is a grotesque image of a hand somewhere ...
# 26                                                  NaN
# 27    There is a hand lying out on a blanket. The ha...
# 28    red and white flesh like substance. some round...
# 29                                                  NaN
# ...                                                 ...
# 1608  The man is old and lonely. He may be waiting f...
# 1609  a man with a large mustache is seen smiling at...
# 1610  This is an image of a man in a happy mood who ...
# 1611  This man is very happy but the smile fails to ...
# 1612  A man is resting on a window sill. It is winte...
# 1613  An old man is looking out the window. It is da...
# 1614  man looking out the window. looks pensive. and...
# 1615  This is an image of a baby holding a finger an...
# 1616  pensive. laying by himself. Don't feel too bad...
# 1617  The baby seems to be secure holding the finger...
# 1618  A man is laying on a ledge under a window. He ...
# 1619  a baby is seen holding a person's finger. the ...
# 1620  A happy and smiling man. He has long black hai...
# 1621  a man is seen lying on a window sill. He has b...
# 1622  A person is laying next to a window. They are ...
# 1623  A naked baby is reaching out and holding a gua...
# 1624  The man seems ot be just chilling; it is a cla...
# 1625  This is a picture of a baby looking curiously ...
# 1626  There is a guy smiling at the camera. He has a...
# 1627  a guy is looking at me kind of crazy. i think ...
# 1628  This is a picture of a baby. The baby is looki...
# 1629  dang, go off sis. she looks like she's having ...
# 1630  an elderly gentleman is looking outside his wi...
# 1631  This is an image of an old man that is looking...
# 1632  A woman wearing a denim shirt is smiling at th...
# 1633  Blonde woman enjoying the sandy beach and warm...
# 1634  Man is uncovering his window; there is nothing...
# 1635  This is a woman sitting on the beach. She seem...
# 1636  There is an old man looking out of a window. H...
# 1637  This is a picture of a man. The man has a smil...
#
#                                                response     score    observed
# 0     this is a photo of a man and woman who look li...  2.100000   81.023633
# 1     this is a cut off hand. it looks really bloody...  2.222222   89.457537
# 2                                                   NaN       NaN         NaN
# 3     There was a couple arguing, with what looks li...  1.800000   66.236203
# 4     this looks like a police officer pushing down ...  2.200000  100.636141
# 5     there is a woman looking down and to the side ...  1.800000   79.859059
# 6     This is a picture of a hand that has been cut ...  2.300000   79.549093
# 7                                                   NaN       NaN         NaN
# 8     The baby was in the hospital. The baby seemed ...  1.666667   58.624194
# 9     There was a situation that involved police and...  2.400000   60.465709
# 10    In the past, a man holds a sobbing child. Why ...  4.333333   53.674585
# 11    Its the future, a newborn is in the NICU recei...  4.750000   55.007744
# 12    There was an argument where a guy was berating...  1.400000   65.290495
# 13                                                  NaN       NaN         NaN
# 14    A police officer is arresting someone in the p...  2.222222   68.495694
# 15    A woman was beaten badly and her face is blood...  5.400000   62.898658
# 16    A very sick child is hooked up to a lot of mac...  3.333333   65.049157
# 17    A baby is having a treatment in an emergency r...  2.000000   61.878186
# 18    Two people are in an argument while their soni...  2.900000   61.251569
# 19    In the past a boy has a gash in his face. It's...  4.400000   50.300928
# 20    Two adults are arguing at each other, and a bo...  1.300000   52.077568
# 21                                                  NaN       NaN         NaN
# 22    Bloody face, white individual. very white righ...  1.000000   24.160701
# 23    A couple is having an argument some time ago i...  2.700000   70.922973
# 24    A man is yelling at a woman and is pointing hi...  1.800000   53.778818
# 25    This is a grotesque image of a hand somewhere ...  3.300000   56.575875
# 26                                                  NaN       NaN         NaN
# 27    There is a hand lying out on a blanket. The ha...  1.900000   50.890839
# 28    red and white flesh like substance. some round...  1.000000   36.600250
# 29                                                  NaN       NaN         NaN
# ...                                                 ...       ...         ...
# 1608  The man is old and lonely. He may be waiting f...  1.555556   31.295683
# 1609  a man with a large mustache is seen smiling at...  1.000000   62.176504
# 1610  This is an image of a man in a happy mood who ...  1.875000   61.699111
# 1611  This man is very happy but the smile fails to ...  1.000000   39.601174
# 1612  A man is resting on a window sill. It is winte...  1.000000   39.596039
# 1613  An old man is looking out the window. It is da...  1.000000   80.819826
# 1614  man looking out the window. looks pensive. and...  1.333333   47.074829
# 1615  This is an image of a baby holding a finger an...  1.285714   50.539578
# 1616  pensive. laying by himself. Don't feel too bad...  1.333333   32.406793
# 1617  The baby seems to be secure holding the finger...  1.000000   51.108144
# 1618  A man is laying on a ledge under a window. He ...  1.000000   76.993434
# 1619  a baby is seen holding a person's finger. the ...  1.000000   60.072883
# 1620  A happy and smiling man. He has long black hai...  1.125000   34.051901
# 1621  a man is seen lying on a window sill. He has b...  1.000000   68.323897
# 1622  A person is laying next to a window. They are ...  1.000000   63.682575
# 1623                                                NaN       NaN         NaN
# 1624  The man seems ot be just chilling; it is a cla...  1.000000   46.396924
# 1625  This is a picture of a baby looking curiously ...  1.333333   41.442211
# 1626  There is a guy smiling at the camera. He has a...  1.000000   82.399447
# 1627  a guy is looking at me kind of crazy. i think ...  1.500000   39.915168
# 1628  This is a picture of a baby. The baby is looki...  1.000000   70.769534
# 1629  dang, go off sis. she looks like she's having ...  1.000000   50.411830
# 1630  an elderly gentleman is looking outside his wi...  1.000000   66.330858
# 1631                                                NaN       NaN         NaN
# 1632  A woman wearing a denim shirt is smiling at th...  1.000000   85.300132
# 1633  Blonde woman enjoying the sandy beach and warm...  1.100000   38.432223
# 1634  Man is uncovering his window; there is nothing...  1.000000   52.517270
# 1635  This is a woman sitting on the beach. She seem...  1.000000   52.930222
# 1636  There is an old man looking out of a window. H...  1.000000   56.257716
# 1637  This is a picture of a man. The man has a smil...  1.000000   82.904233
#
# [1638 rows x 16 columns]
